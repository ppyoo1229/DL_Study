# %%
Unexpected token 'i', "import tor"... is not valid JSON
SyntaxError: Unexpected token 'i', "import tor"... is not valid JSON
    at JSON.parse (<anonymous>)
    at wa.program_ (https://ssl.gstatic.com/colaboratory-static/common/db4ee20e2609abca229d8f786201eaac/external_binary_l10n__ko.js:3658:262)
    at ya (https://ssl.gstatic.com/colaboratory-static/common/db4ee20e2609abca229d8f786201eaac/external_binary_l10n__ko.js:16:57)
    at wa.next_ (https://ssl.gstatic.com/colaboratory-static/common/db4ee20e2609abca229d8f786201eaac/external_binary_l10n__ko.js:14:195)
    at kaa.next (https://ssl.gstatic.com/colaboratory-static/common/db4ee20e2609abca229d8f786201eaac/external_binary_l10n__ko.js:17:48)
    at b (https://ssl.gstatic.com/colaboratory-static/common/db4ee20e2609abca229d8f786201eaac/external_binary_l10n__ko.js:17:309)
# Out:
# svmem(total=16773271552, available=5658877952, percent=66.3, used=11114393600, free=5658877952)
