# %% [markdown]
# # 01-1 딥러닝을 위한 도구

# %% [markdown]
# ### # 1. 파이썬 리스트

# %%
my_list = [10, 'hello list', 20]
print(my_list[1]) # 인덱스 1
# Out:
# hello list

# %%
# 2차원 배열 리스트
my_list_2 = [[10, 20, 30], [40, 50, 60]]
print(my_list_2[1][1])
# Out:
# 50

# %% [markdown]
# ### 2. Numpy

# %%
import numpy as np

# %%
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
my_arr
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %% [markdown]
# ### 3. Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### - 선 그래프 그리기

# %%
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25]) # x 좌표와 y 좌표를 파이썬 리스트로 전달합니다.
plt.show()

# %% [markdown]
# ### - 산점도(scatter plot) 그리기

# %%
plt.scatter([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %% [markdown]
# ### - 넘파이 배열로 산점도 그리기

# %%
x = np.random.randn(1000) # 표준 정규 분포를 따르는 난수 1,000개
y = np.random.randn(1000) # 표준 정규 분포를 따르는 난수 1,000개
plt.scatter(x, y)
plt.show()
